# %%
from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):        
        print ('Start :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
    def handle_endtag(self, tag):
        print ('End   :',tag)
        
    def handle_startendtag(self, tag, attrs):
        print ('Empty :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
MyParser = MyHTMLParser()
MyParser.feed(''.join([input().strip() for _ in range(int(input()))]))

# %%
import sys #kvuli argumentum (argv)
import random #kvuli fci randint(pocatecni hodnota, koncova hodnota)

if len(sys.argv) > 1: #pokud je argument value > 1
    arg = sys.argv[1]
else:
    arg = False

def generate_bn():
    bd = input("Date of birdth [YYYY-MM-DD]: ")
    sex = input("Sex: ")

    year = int(bd[0:4])
    part1 = bd.replace('-','')[2:]
    print(part1) #YYYYMMDD
    print(year) #vypise rok narozeni 

    while True:
        if year < 1954:
            part2 = random.randint(0,999)
            f_inc = 5000000
            if part2 < 10:
                part2 = ('00' + str(part2))
            elif part2 < 100 and part2>= 10:
                part2 = ('0' + str(part2))

        else:
            part2 = random.randint(0,9999)
            f_inc = 50000000
            if part2 < 10:
                part2 = ('000' + str(part2))
            elif part2 < 100 and part2 >= 10:
                part2 = ('00' + str(part2))
            elif part2 < 1000 and part2 >= 100:
                part2 = ('0' + str(part2))

        num = int(str(part1)+str(part2))
        if sex=='F':
            num += f_inc

        if(num % 11 == 0):
            break
    print('Delka kontrolniho cisla je: ' + str(len(str(part2))))
    print(num)

def is_valid_bn(num):
    valid = True
    if(num % 11 != 0):
        valid = False

    if(len(num) != 9 and int(num[:2]) < 54):
        valid = False

    if(len(num) != 10 and int(num[:2]) >= 54):
        valid = False
        
    print(valid)

if arg:
   is_valid_bn(arg)
else:
   generate_bn()
